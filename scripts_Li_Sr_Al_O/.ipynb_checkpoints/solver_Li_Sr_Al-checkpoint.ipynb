# %%
# import numpy as np
# import json
# from scipy.spatial import distance_matrix
# import matplotlib.pyplot as plt
# import sys
# sys.path.append('C:\\\\Users\\\\dell\\\\Desktop\\\\phasemapy')
# import os
# from copy import deepcopy
# from scipy.constants import h, c, e
# from pymatgen.core import Element
# from monty.json import MontyDecoder, MontyEncoder
# from pymatgen.analysis.diffraction.xrd import XRDCalculator
# import numpy as np
# from phasemapy.dataio import InstanceData
# from phasemapy.parser import ICDDEntry,ICDDEntriesBiCuV, ICDDEntryPreprocessor
# from phasemapy.solver import Phase, Sample
# import matplotlib.pyplot as plt
# chemsys = ['Li', 'Sr', 'Al']
# oxide_system = True
# photon_e = 13e3
# max_q_shift = 0.05
# resample_density = 1000
# initial_alphagamma = 0.1
# SUM_NORM = 6000
# loss_weight = {'xrd_loss': 6.0, 'comp_loss': 2.0, 'entropy_loss': 0.01}

# %%
import warnings
warnings.filterwarnings('ignore')
import json, os
from scipy.spatial import distance_matrix
import numpy as np
from monty.json import MontyDecoder, MontyEncoder
from copy import deepcopy
import sys
sys.path.append('C:\\Users\\dell\\Desktop\\phasemapy')

from phasemapy.dataio import InstanceData
from phasemapy.parser import ICDDEntry
from phasemapy.solver import Phase, Sample

chemsys = ['Li', 'Sr', 'Al']
oxide_system = True
photon_e = 13e3
max_q_shift = 0.05
resample_density = 1000
initial_alphagamma = 0.1
SUM_NORM = 6000
loss_weight = {'xrd_loss': 6.0, 'comp_loss': 2.0, 'entropy_loss': 0.01}

# %%
#load instance data:50 instances
instance_data = InstanceData.from_json('./data/Instance_data', chemsys, photon_e)
instance_data.renormalize(norm=SUM_NORM)
#load entry pool: 37 ICDD entries
with open('./data/ICDD_entries.json') as f:
    entries = json.load(f, cls=MontyDecoder)
entries = [ICDDEntry.from_icdd_json(en) for en in entries]

# %% [markdown]
# 1.Find the major phases

# %%
samples = []
for i in range(instance_data.sample_num):    
    solution = []
    for e in entries:
        phase = Phase.from_entry_and_instance_data(e, 1 / len(entries), instance_data)
        solution.append(phase)  
        
    sample = Sample(i, instance_data.log_q, instance_data.sample_xrd[i], instance_data.chemsys,
                    instance_data.sample_comp[i], oxide_system, instance_data.wavelength, max_q_shift, solution)
    sample.prune_candidates_based_on_composition(cutoff=0.005)
    sample.prune_candidate_based_on_xrd(plot=True, cutoff=0.005)
    sample.refine_all_fractions()
#     sample.update_solution_new(0.03,0.2999,sample.max_q_shift)
#     sample.refine_one_by_one()
#     sample.plot(perphase=True)
    samples.append(sample)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18008\1467462254.py in <module>
#       9                     instance_data.sample_comp[i], oxide_system, instance_data.wavelength, max_q_shift, solution)
#      10     sample.prune_candidates_based_on_composition(cutoff=0.005)
# ---> 11     sample.prune_candidate_based_on_xrd(plot=True, cutoff=0.005)
#      12     sample.refine_all_fractions()
#      13 #     sample.update_solution_new(0.03,0.2999,sample.max_q_shift)
#
# ~\Desktop\phasemapy\phasemapy\solver.py in prune_candidate_based_on_xrd(self, extension, plot, saveplot, cutoff)
#     260         for phase in self.solution:
#     261
# --> 262             amp, weight = self.get_voigt_xrd(wider_q, *phase.entry.data['xrd'], initial_alphagamma, self.wavelength)
#     263             amp = amp / np.max(amp) * 100
#     264
#
# ~\Desktop\phasemapy\phasemapy\solver.py in get_voigt_xrd(q_vectors, q_loc, intensity, alphagamma, wavelength)
#     191
#     192         alphagamma = alphagamma * 1 / np.cos(np.arcsin(np.array(q_loc) / np.pi / 2 / 10 * wavelength / 2))
# --> 193         data = Voigt(q_vectors, q_loc, alphagamma, intensity)  # *intensity.reshape(1,-1)
#     194         weight = SUM_NORM / np.sum(data)
#     195         data = data * weight  # low weight means strong diffraction (Riet-sum coeff * weight = volume fraction)
#
# ~\Desktop\phasemapy\phasemapy\solver.py in Voigt(x, c, alphagamma, amps)
#     185             gamma = 0.61065 * alphagamma
#     186             sigma = alpha / np.sqrt(2 * np.log(2))
# --> 187             profile = np.real(wofz(((x - c) + 1j * gamma) / (sigma * np.sqrt(2)))) / (sigma * np.sqrt(2 * np.pi))
#     188             profile *= amps
#     189             profile = np.sum(profile, axis=1)
#
# KeyboardInterrupt:

# %%
comp_dist = distance_matrix(instance_data.sample_comp, instance_data.sample_comp)
nn_list = {i: np.where((comp_dist[i] < 0.15) & (comp_dist[i] > 0))[0] for i in range(instance_data.sample_num)}
new_samples=deepcopy(samples)
for sample in new_samples:    
    if len(sample.phase_fractions)==0:
        sample.solution = new_samples[sample.sample_id-1].solution
    if len(sample.phase_fractions)>0:
        candidate_entries = []
        for i in nn_list[sample.sample_id]:
            candidate_entries += new_samples[i].entries
        candidate_entries = list(set(candidate_entries))
        solution = []
        for e in candidate_entries:
            phase = Phase.from_entry_and_instance_data(e, 1 / len(candidate_entries), instance_data)
            solution.append(phase)
    new_sample = deepcopy(sample)
    new_sample.solution = solution

#     new_sample = new_sample.optimize(num_epoch=500, print_prog=True, loss_weight=loss_weight)
    new_sample.print_solution()
#     new_sample.update_solution_new(0.01, 0.2999, new_sample.max_q_shift)
    
    new_sample.refine_all_fractions()
    new_sample.update_solution(0.008, 0.2999, new_sample.max_q_shift)
    new_sample.print_solution_new()
    new_sample.refine_one_by_one()
#     new_sample.update_solution_new(0.01, 0.2999, new_sample.max_q_shift)
#     new_sample.refine_all_fractions()
#     new_sample.refine_one_by_one()
#     new_sample.print_solution()
#     new_sample.update_solution_new(0.015, 0.2999, new_sample.max_q_shift)
#     new_sample.refine_all_fractions()
#     new_sample.refine_one_by_one()
#     new_sample.print_solution()
    new_sample.plot(perphase=True)
#     new_samples.append(new_sample)
#     solution_file = f'solution/samples{sample.sample_id}.json'
#     with open(solution_file, 'w') as f:
#         json.dump( new_sample, f, cls=MontyEncoder)

# %%
#     def update_solution_height_fractions(sample,frac_cutoff, width_cutoff, shift):
#         s = []
#         for phase, height in zip(sample.solution, sample.height_factions):
#             if height > frac_cutoff:
#                 s.append(phase)

#         sample.solution = s
#         sample.solution = [_ for _ in sample.solution if _.width < width_cutoff - 1e-8]
#         sample.solution = [_ for _ in sample.solution if abs(_.shift) < shift - 1e-8]

# %%
new_samples = deepcopy(samples)
for sample in new_samples:
    sample.print_solution()
    sample.update_solution_new(0.02,0.2999,sample.max_q_shift)
    sample.print_solution()
    sample.update_solution_height_fractions( 0.05,0.2999, sample.max_q_shift)
    sample.print_solution()
# Out:
# Sample: # 0
#     Name     Entry_id  phase_fraction  fraction  height_fraction     shift  width
# 0    SrO  01-075-6979        0.853128  0.859134         0.853252  0.001993   0.03
# 1  Al2O3  01-089-7717        0.051640  0.092567         0.051238  0.005979   0.03
# 2   Li2O  04-014-6071        0.095231  0.048300         0.095509  0.003986   0.03
# Current R^2 = 0.5583497332755025
# Sample: # 0
#     Name     Entry_id  phase_fraction  fraction  height_fraction     shift  width
# 0    SrO  01-075-6979        0.853128  0.859134         0.853252  0.001993   0.03
# 1  Al2O3  01-089-7717        0.051640  0.092567         0.051238  0.005979   0.03
# 2   Li2O  04-014-6071        0.095231  0.048300         0.095509  0.003986   0.03
# Current R^2 = 0.5583497332755025
# Sample: # 0
#     Name     Entry_id  phase_fraction  fraction  height_fraction     shift  width
# 0    SrO  01-075-6979        0.853128  0.859134         0.853252  0.001993   0.03
# 1  Al2O3  01-089-7717        0.051640  0.092567         0.051238  0.005979   0.03
# 2   Li2O  04-014-6071        0.095231  0.048300         0.095509  0.003986   0.03
# Current R^2 = 0.5583497332755025
# Sample: # 1
#            Name     Entry_id  phase_fraction  fraction  height_fraction     shift  width
# 
name     Entry_id  phase_fraction  fraction  height_fraction     shift  width
# 0           SrO  01-075-6979        0.679086  0.682666         0.677330  0.003986   0.03
# 1         Al2O3  01-089-7717        0.117561  0.210360         0.117376  0.005979   0.03
# 2          Li2O  04-014-6071        0.192699  0.097562         0.194473  0.003986   0.03
# 3     LiAl2O3.5  04-018-1382        0.007892  0.007721         0.008109  0.045837   0.03
# 4  (Al2O3)1.333  01-075-0921        0.002763  0.001691         0.002712  0.035873   0.03
# Current R^2 = 0.7420599641421505
# Sample: # 7
#     Name     Entry_id  phase_fraction  fraction  height_fraction     shift  width
# 0    SrO  01-075-6979        0.686399  0.689152         0.684739  0.003986   0.03
# 1  Al2O3  01-089-7717        0.118827  0.212359         0.118660  0.005979   0.03
# 2   Li2O  04-014-6071        0.194775  0.098489         0.196600  0.003986   0.03
# Current R^2 = 0.742375195929526
# Sample: # 7
#     Name     Entry_id  phase_fraction  fraction  height_fraction     shift  width
# 0    SrO  01-075-6979        0.686399  0.689152         0.684739  0.003986   0.03
# 1  Al2O3  01-089-7717        0.118827  0.212359         0.118660  0.005979   0.03
# 2   Li2O  04-014-6071        0.194775  0.098489         0.196600  0.003986   0.03
# Current R^2 = 0.742375195929526

# %%
for sample in samples:
    solution_file = f'solution/samples{sample.sample_id}.json'
    with open(solution_file, 'w') as f:
        json.dump( sample, f, cls=MontyEncoder)

# %%
comp_dist = distance_matrix(instance_data.sample_comp, instance_data.sample_comp)
nn_list = {i: np.where((comp_dist[i] < 0.15) & (comp_dist[i] > 0))[0] for i in range(instance_data.sample_num)}
samples = []
for i in range(instance_data.sample_num):
    solution_file = f'solution/samples{i}.json'
    if os.path.exists(solution_file):
        with open(solution_file) as f:
            sample = json.load(f, cls=MontyDecoder)
            samples.append(sample)

# %%
new_samples=[]
for sample in samples:
    if True:      
        if len(sample.phase_fractions)==0:
            sample.solution = samples[sample.sample_id-1].solution
        if len(sample.phase_fractions)>0:
            candidate_entries = []
            for i in nn_list[sample.sample_id]:
                candidate_entries += samples[i].entries
            candidate_entries = list(set(candidate_entries))
            solution = []
            for e in candidate_entries:
                phase = Phase.from_entry_and_instance_data(e, 1 / len(candidate_entries), instance_data)
                solution.append(phase)
        new_sample = deepcopy(sample)
        new_sample.solution = solution        
#         new_sample = new_sample.optimize(num_epoch=500, print_prog=True, loss_weight=loss_weight)
        new_sample.print_solution()
#         new_sample.update_solution_new(0.01, 0.2999, new_sample.max_q_shift)
        
        new_sample.refine_all_fractions()
        new_sample.refine_one_by_one()
        new_sample.update_solution_new(0.01, 0.2999, new_sample.max_q_shift)
        new_sample.refine_all_fractions()
        new_sample.refine_one_by_one()
        new_sample.print_solution()
        new_sample.update_solution_new(0.015, 0.2999, new_sample.max_q_shift)
        new_sample.refine_all_fractions()
        new_sample.refine_one_by_one()
        new_sample.print_solution()
        new_sample.plot(perphase=True)
        new_samples.append(new_sample)
        solution_file = f'solution/samples{sample.sample_id}.json'
        with open(solution_file, 'w') as f:
            json.dump( new_sample, f, cls=MontyEncoder)

# %%
for sample in new_samples:
    sample.plot(perphase=True, saveplot=f'solution_figures/sample_{sample.sample_id}.pdf')

# %%
for sample in samples[0:10]:
    if True:      
        if len(sample.phase_fractions)==0:
            sample.solution = samples[sample.sample_id-1].solution
        if len(sample.phase_fractions)>0:
            candidate_entries = []
            for i in nn_list[sample.sample_id]:
                candidate_entries += samples[i].entries
            candidate_entries = list(set(candidate_entries))
            solution = []
            for e in candidate_entries:
                phase = Phase.from_entry_and_instance_data(e, 1 / len(candidate_entries), instance_data)
                solution.append(phase)
        new_sample = deepcopy(sample)
        new_sample.solution = solution        
        new_sample = new_sample.optimize(num_epoch=500, print_prog=True, loss_weight=loss_weight)
        new_sample.print_solution()
        new_sample.update_solution_new(0.01, 0.2999, new_sample.max_q_shift)
        new_sample.print_solution()
        new_sample.refine_all_fractions()
        new_sample.refine_one_by_one()
        new_sample.plot(perphase=True)
#         samples[sample.sample_id] = new_sample
#         solution_file = f'solution/samples{sample.sample_id}.json'
#         with open(solution_file, 'w') as f:
#             json.dump( samples[sample.sample_id], f, cls=MontyEncoder)
            
# # Save the minor phases
# for sample in samples:
#     sample.plot(perphase=True, saveplot=f'solution_figures/sample_{sample.sample_id}.pdf')

# %%
samples[18].print_solution()
samples[18].update_solution_new(0.01,0.2999,samples[17].max_q_shift)
samples[18].print_solution()

# %%
for sample in samples:
    sample.update_solution_new(0.01,0.2999,sample.max_q_shift)
    sample = sample.optimize(num_epoch=500, print_prog=True, loss_weight=loss_weight)
    sample.refine_all_fractions()
    sample.refine_one_by_one()
    sample.plot(perphase=True)
#     samples[sample.sample_id] = new_sample
    solution_file = f'solution/samples{sample.sample_id}.json'
    with open(solution_file, 'w') as f:
        json.dump( sample, f, cls=MontyEncoder)

# %%
# Save the minor phases
for sample in samples:
    sample.plot(perphase=True, saveplot=f'solution_figures/sample_{sample.sample_id}.pdf')

# %%
new_samples=deepcopy(samples)

# %%
for sample in new_samples:
    if True:      
        if len(sample.phase_fractions)==0:
            sample.solution = samples[sample.sample_id-1].solution
        if len(sample.phase_fractions)>0:
            candidate_entries = []
            for i in nn_list[sample.sample_id]:
                candidate_entries += samples[i].entries
            candidate_entries = list(set(candidate_entries))
            solution = []
            for e in candidate_entries:
                phase = Phase.from_entry_and_instance_data(e, 1 / len(candidate_entries), instance_data)
                solution.append(phase)
        new_sample = deepcopy(sample)
        new_sample.solution = solution        
        new_sample = new_sample.optimize(num_epoch=500, print_prog=True, loss_weight=loss_weight)
        new_sample.update_solution_new(0.1, 0.2999, new_sample.max_q_shift)
        new_sample.refine_all_fractions()
        new_sample.refine_one_by_one()
        new_sample.plot(perphase=True)
#         samples[sample.sample_id] = new_sample
#         solution_file = f'solution/samples{sample.sample_id}.json'
#         with open(solution_file, 'w') as f:
#             json.dump( samples[sample.sample_id], f, cls=MontyEncoder)

# %%
new_samples[10].print_solution_new()

# %%
for i in range(instance_data.sample_num):
    solution_file = f'solution/samples{i}.json'
    if os.path.exists(solution_file):
        with open(solution_file) as f:
            sample = json.load(f, cls=MontyDecoder)
            samples.append(sample)

# %%
new_samples = deepcopy(samples)

# %%
for sample in new_samples:
    if True:      
        if len(sample.phase_fractions)==0:
            sample.solution = new_samples[sample.sample_id-1].solution
        if sample.R > 0.4 and len(sample.phase_fractions)>0:
#         print(sample.sample_id, sample.loss(loss_weight))
            candidate_entries = []
            for i in nn_list[sample.sample_id]:
                candidate_entries += samples[i].entries
            candidate_entries = list(set(candidate_entries))
            solution = []
            for e in candidate_entries:
                phase = Phase.from_entry_and_instance_data(e, 1 / len(candidate_entries), instance_data)
                solution.append(phase)

            new_sample = deepcopy(sample)
            new_sample.solution = solution            
            new_sample.refine_one_by_one()
            new_sample.refine_all_fractions()
#             new_sample.print_solution()
            new_sample.prune_candidate_based_on_xrd(plot=False, cutoff=0.001)
            new_sample.update_solution_new(0.03,0.2999,new_sample.max_q_shift)
            new_sample.refine_one_by_one()
            new_sample.refine_all_fractions()
#             new_sample.print_solution()
#             new_sample.plot(perphase=True)
            # au = new_sample.to_auto
            new_sample = new_sample.optimize(num_epoch=500, print_prog=True, loss_weight=loss_weight)
            new_sample.update_solution_new(0.03, 0.2999, new_sample.max_q_shift)

            new_sample = new_sample.optimize(num_epoch=3000, print_prog=True, loss_weight=loss_weight)
            new_sample.update_solution_new(0.01, 0.2999, new_sample.max_q_shift)

            new_sample.refine_one_by_one()
            new_sample.refine_all_fractions()

            new_sample.update_solution_new(0.01, 0.2999, new_sample.max_q_shift)
            new_sample.refine_one_by_one()
            new_sample.refine_all_fractions()
#             new_sample.print_solution()
#             new_sample.plot(perphase=True)
#             new_samples[sample.sample_id] = new_sample
            samples[sample.sample_id] = new_sample

            print(new_sample.loss(loss_weight))
            if new_sample.loss(loss_weight) <= sample.loss(loss_weight):
#                 sample.print_solution()
#                 new_sample.print_solution()
                samples[sample.sample_id] = new_sample
                solution_file = f'solution/samples{sample.sample_id}.json'
                with open(solution_file, 'w') as f:
                    json.dump( samples[sample.sample_id], f, cls=MontyEncoder)

# %%
new_samples = []

for i in range(instance_data.sample_num):
    solution_file = f'solution/samples{i}.json'
    if os.path.exists(solution_file):
        with open(solution_file) as f:
            sample = json.load(f, cls=MontyDecoder)
            new_samples.append(sample)

for sample in new_samples:
    sample.plot(perphase=True, saveplot=f'solution_figures/sample_{sample.sample_id}.pdf')

# %% [markdown]
# 2.Find more accurate solutions

# %%
comp_dist = distance_matrix(instance_data.sample_comp, instance_data.sample_comp)
nn_list = {i: np.where((comp_dist[i] < 0.15) & (comp_dist[i] > 0))[0] for i in range(instance_data.sample_num)}
samples = []

for i in range(instance_data.sample_num):
    solution_file = f'solution/samples{i}.json'
    if os.path.exists(solution_file):
        with open(solution_file) as f:
            sample = json.load(f, cls=MontyDecoder)
            samples.append(sample)

# %%
new_samples = deepcopy(samples)

# %%
for sample in new_samples[170:]:
    if True:        
        if len(sample.phase_fractions)==0:
            sample.solution = new_samples[sample.sample_id-1].solution
            sample.phase_fractions = new_samples[sample.sample_id-1].phase_fractions
        if len(sample.phase_fractions)>0:
#         print(sample.sample_id, sample.loss(loss_weight))
            candidate_entries = []
            for i in nn_list[sample.sample_id]:
                candidate_entries += samples[i].entries
            candidate_entries = list(set(candidate_entries))
            solution = []
            for e in candidate_entries:
                phase = Phase.from_entry_and_instance_data(e, 1 / len(candidate_entries), instance_data)
                solution.append(phase)

            new_sample = deepcopy(sample)
            new_sample.solution = solution            
            new_sample.refine_one_by_one()
            new_sample.refine_all_fractions()
#             new_sample.print_solution()

            new_sample.update_solution_new(0.1,0.2999,new_sample.max_q_shift)
#             new_sample.print_solution()
            new_sample.refine_one_by_one()
            new_sample.refine_all_fractions()
            
            new_sample.update_solution_new(0.05,0.2999,new_sample.max_q_shift)
#             new_sample.print_solution()
#             new_sample.plot(perphase=True)
#             if new_sample.loss(loss_weight) <= sample.loss(loss_weight):
#                 sample.print_solution()
#                 new_sample.print_solution()
            samples[sample.sample_id] = new_sample
            solution_file = f'solution/samples{sample.sample_id}.json'
            with open(solution_file, 'w') as f:
                json.dump( samples[sample.sample_id], f, cls=MontyEncoder)

# %%
samples = []

for i in range(instance_data.sample_num):
    solution_file = f'solution/samples{i}.json'
    if os.path.exists(solution_file):
        with open(solution_file) as f:
            sample = json.load(f, cls=MontyDecoder)
            samples.append(sample)

# %%
for sample in samples:
#     sample.plot(perphase=True, saveplot=f'solution_figures/sample_{sample.sample_id}.pdf')

# %%
new_samples = deepcopy(samples)

# %%
for sample in samples:
    sample.plot(perphase=True)

# %%
for sample in samples:
    if len(sample.phase_fractions)==0:
                sample.solution = new_samples[sample.sample_id-1].solution
    if len(sample.phase_fractions)>0:
        print(sample.sample_id, sample.loss(loss_weight))
        candidate_entries = []
        for i in nn_list[sample.sample_id]:
            candidate_entries += samples[i].entries
        candidate_entries = list(set(candidate_entries))
        solution = []
        for e in candidate_entries:
            phase = Phase.from_entry_and_instance_data(e, 1 / len(candidate_entries), instance_data)
            solution.append(phase)
    
        new_sample = deepcopy(sample)
        new_sample.solution = solution            
    #     new_sample.refine_one_by_one()
        new_sample.refine_all_fractions()
        new_sample.plot(perphase=True)
        new_sample = new_sample.optimize(num_epoch=500, print_prog=True, loss_weight=loss_weight)
        new_sample.update_solution_new(0.05, 0.2999, new_sample.max_q_shift)
#         new_sample.print_solution_new()
#         new_sample.print_solution()
        new_sample.plot(perphase=True)
        samples[sample.sample_id] = new_sample
        solution_file = f'solution/samples{sample.sample_id}.json'
        with open(solution_file, 'w') as f:
            json.dump( samples[sample.sample_id], f, cls=MontyEncoder)

# %%
# Save the minor phases
for sample in samples:
    sample.plot(perphase=True, saveplot=f'solution_figures/sample_{sample.sample_id}.pdf')

# %%
new_samples = deepcopy(samples)

# %%
# Remove the minor phases
for sample in new_samples:
    sample.update_solution_new(0.08, 0.2999, sample.max_q_shift)
    sample.plot(perphase=True)
    new_samples[sample.sample_id] = sample
    solution_file = f'solution/samples{sample.sample_id}.json'
    with open(solution_file, 'w') as f:
        json.dump(new_samples[sample.sample_id], f, cls=MontyEncoder)

# %%
for sample in new_samples:
    sample.plot(perphase=True, saveplot=f'solution_figures/sample_{sample.sample_id}.pdf')
